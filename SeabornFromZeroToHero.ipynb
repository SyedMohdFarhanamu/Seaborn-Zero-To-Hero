# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pwd
# Out:
# 'E:\\Data_Scinece\\jupyter'

# %%
t = pd.read_csv('E:\\Data_Scinece\\jupyter\\tips.csv')

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# # Histogram/Dist Plot

# %%
sns.distplot(tips['tip'])
plt.show()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['tip'], bins=10)
plt.show()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * tip variable is right skewed

# %%
sns.distplot(tips['tip'],bins=10, kde=False)
plt.show()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='time')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='time',size='size')
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker', style='time',size='size')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker',col='day')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker',size='size',style='time', col='day',col_wrap=2)

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(y='tip', x='total_bill', data=tips)
plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, vars=['total_bill','tip'])
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %% [markdown]
# # Line Plot

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0 -0.577072
# 1     1 -1.503029
# 2     2 -1.354729
# 3     3 -2.773002
# 4     4 -2.293494

# %%
sns.relplot(x='time', y='value', kind='line', data=df)
plt.show()

# %%
sns.set_style('whitegrid')
sns.relplot(x='time', y='value', kind='line', data=df)

# %%
sns.set_style('darkgrid')
sns.relplot(x='time', y='value', kind='line', data=df)

# %%
sns.set_style("white")

# %% [markdown]
# # Heat Plot

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
plt.show()

# %%
sns.heatmap(tips.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Categorical(Discrete) Plot

# %% [markdown]
# # Count Plot

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(y='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x=tips['sex'], y=tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x=tips['sex'], y=tips['total_bill']).set_title('Barplot')
# Out:
# Text(0.5, 1.0, 'Barplot')

# %%
sns.barplot(x=tips['sex'], y=tips['total_bill'])
plt.title("Barplot")
# Out:
# Text(0.5, 1.0, 'Barplot')

# %%
sns.barplot(x='total_bill', y='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(x='day', y='total_bill', data=tips, hue='size')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(tips['total_bill'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.boxplot(data=tips)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot('smoker','total_bill', data=tips)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(y='total_bill', x='day', hue='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(y='total_bill', x='day', data=tips, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Cat Plot

# %%
sns.barplot(x='day', y='total_bill', data=tips, hue='size')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day', y='total_bill', kind='bar', data=tips, hue='size')

# %%
sns.catplot(x='smoker', y='total_bill', kind='box', data=tips, hue='sex')

# %%
sns.catplot(x='smoker', kind='count', data=tips)

# %%
sns.catplot(x='day', y='total_bill', data=tips)
# sns.catplot(x='day', y='total_bill',kind='strip', data=tips)

# %%
help(sns.catplot)
# Out:
# Help on function catplot in module seaborn.categorical:
#
# catplot(*, x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x000001DD6C2F5790>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)
#     Figure-level interface for drawing categorical plots onto a FacetGrid.
#
#     This function provides access to several axes-level functions that
#     show the relationship between a numerical and one or more categorical
#     variables using one of several visual representations. The ``kind``
#     parameter selects the underlying axes-level function to use:
#
#     Categorical scatterplots:
#
#     - :func:`stripplot` (with ``kind="strip"``; the default)
#     - :func:`swarmplot` (with ``kind="swarm"``)
#
# ...

# %%
sns.catplot(x='smoker', y='tip', data=tips, kind='bar')

# %%
sns.catplot(x='smoker', y='tip', data=tips, kind='bar', order=['No', 'Yes'])

# %%
sns.catplot(x='day', kind='count', data=tips, hue='size')

# %% [markdown]
# # Voilin Plot

# %%
sns.violinplot(x='total_bill', y='day', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x='total_bill', y='day', data=tips, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>
